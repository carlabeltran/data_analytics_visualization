# %%
# Dependencies
import json
import os
from pprint import pprint

# Load JSON
filepath = os.path.join("..", "Resources", "youtube_response.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)
#     pprint(json_data)
    print(f"The video's title is {json_data['data']['items'][0]['title']}.")
    print(f"The video's rating is {json_data['data']['items'][0]['rating']}.")
    print(f"The link to the video thumbnail is {json_data['data']['items'][0]['thumbnail']['default']}.")
    print(f"The video has {json_data['data']['items'][0]['viewCount']} views.")
# Out:
# The video's title is Google Developers Day US - Maps API Introduction.
# The video's rating is 4.63.
# The link to the video thumbnail is http://i.ytimg.com/vi/hYB0mn5zh2c/default.jpg.
# The video has 220101 views.
