# %%
# Dependencies
import pandas as pd
import sklearn.datasets as dta
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
# Read in the wine recognition data set from sklearn and load into Pandas
data = dta.load_wine()
wine_data = pd.DataFrame(data.data,columns=data.feature_names)

wine_data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
# Plot malic_acid versus flavanoids on a scatterplot
malic_acid = wine_data["malic_acid"]
flavanoids = wine_data["flavanoids"]
plt.scatter(malic_acid, flavanoids, marker="o", facecolors="red", edgecolors="black", alpha=0.3)
plt.xlabel("Amount of Malic Acid")
plt.ylabel("Amount of Flavanoids")
# Out:
# Text(0, 0.5, 'Amount of Flavanoids')

# %%
# Calculate the correlation coefficient between malic_acid and flavanoids
correlation = st.pearsonr(malic_acid, flavanoids)
print(round(correlation[0], 2))
# Out:
# -0.41

# %%
# Plot alcohol versus colour_intensity on a scatterplot
alcohol = wine_data["alcohol"]
color_intensity = wine_data["color_intensity"]
plt.scatter(alcohol, color_intensity)
plt.xlabel("Amount of Alcohol")
plt.ylabel("Color Intensity")
# Out:
# Text(0, 0.5, 'Color Intensity')

# %%
# Calculate the correlation coefficient between alcohol and color_intensity
correlation = st.pearsonr(alcohol, color_intensity)
print(round(correlation[0], 2))
# Out:
# 0.55

# %%
# BONUS: Generate the correlation matrix and find the strongest positive and negative correlations
# plt.matshow(wine_data.corr())
# plt.show()

corr = wine_data.corr()
corr.style.background_gradient(cmap='coolwarm')

# print(corr.unstack().sort_values())
# Out:
# <style  type="text/css" >
#     #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col1 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col3 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col5 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col6 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col7 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col8 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col9 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col10 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col11 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow0_col12 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col2 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col3 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col4 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col6 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col7 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col9 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col11 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow1_col12 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col0 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col1 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col3 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col4 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col5 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col9 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col10 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col11 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow2_col12 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col1 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col2 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col4 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col9 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col10 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col11 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow3_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col0 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col2 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col5 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_8288f8e6_32da_11ea_a058_fc017c19425crow4_col7 {
#             background-color:  #7597f6;
#             color:
