# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x22b0dcbf4a8>,
#   <matplotlib.axis.XTick at 0x22b0dca6cc0>,
#   <matplotlib.axis.XTick at 0x22b0dca6940>,
#   <matplotlib.axis.XTick at 0x22b0dd78208>,
#   <matplotlib.axis.XTick at 0x22b0dd786a0>,
#   <matplotlib.axis.XTick at 0x22b0dd78b70>,
#   <matplotlib.axis.XTick at 0x22b0dd870b8>,
#   <matplotlib.axis.XTick at 0x22b0dd875c0>,
#   <matplotlib.axis.XTick at 0x22b0dd787f0>,
#   <matplotlib.axis.XTick at 0x22b0dd87a20>,
#   <matplotlib.axis.XTick at 0x22b0dd87e80>,
#   <matplotlib.axis.XTick at 0x22b0dd8d550>,
#   <matplotlib.axis.XTick at 0x22b0dd8dac8>,
#   <matplotlib.axis.XTick at 0x22b0dd920b8>,
#   <matplotlib.axis.XTick at 0x22b0dd925f8>,
#   <matplotlib.axis.XTick at 0x22b0dd92b70>,
#   <matplotlib.axis.XTick at 0x22b0dd9b160>,
#   <matplotlib.axis.XTick at 0x22b0dd92470>,
#   <matplotlib.axis.XTick at 0x22b0dd8d4a8>,
#   <matplotlib.axis.XTick at 0x22b0dd9b550>,
#   <matplotlib.axis.XTick at 0x22b0dd9bba8>,
#   <matplotlib.axis.XTick at 0x22b0dda2160>,
#   <matplotlib.axis.XTick at 0x22b0dda26d8>,
#   <matplotlib.axis.XTick at 0x22b0dda2c50>,
#   <matplotlib.axis.XTick at 0x22b0dda8208>,
#   <matplotlib.axis.XTick at 0x22b0dda8780>,
#   <matplotlib.axis.XTick at 0x22b0dda8cf8>,
#   <matplotlib.axis.XTick at 0x22b0dda8860>,
#   <matplotlib.axis.XTick at 0x22b0dd9bf98>,
#   <matplotlib.axis.XTick at 0x22b0ddb1208>,
#   <matplotlib.axis.XTick at 0x22b0ddb1748>,
#   <matplotlib.axis.XTick at 0x22b0ddb1cc0>,
#   <matplotlib.axis.XTick at 0x22b0ddb5278>,
#   <matplotlib.axis.XTick at 0x22b0ddb57f0>,
#   <matplotlib.axis.XTick at 0x22b0ddb5d68>,
#   <matplotlib.axis.XTick at 0x22b0ddbf320>,
#   <matplotlib.axis.XTick at 0x22b0ddb5320>,
#   <matplotlib.axis.XTick at 0x22b0ddb1550>,
#   <matplotlib.axis.XTick at 0x22b0ddbf668>,
#   <matplotlib.axis.XTick at 0x22b0ddbfda0>,
#   <matplotlib.axis.XTick at 0x22b0ddc5358>,
#   <matplotlib.axis.XTick at 0x22b0ddc58d0>,
#   <matplotlib.axis.XTick at 0x22b0ddc5e48>,
#   <matplotlib.axis.XTick at 0x22b0ddcb400>,
#   <matplotlib.axis.XTick at 0x22b0ddcb978>,
#   <matplotlib.axis.XTick at 0x22b0ddcbef0>,
#   <matplotlib.axis.XTick at 0x22b0ddcba58>,
#   <matplotlib.axis.XTick at 0x22b0dda8828>,
#   <matplotlib.axis.XTick at 0x22b0ddd33c8>,
#   <matplotlib.axis.XTick at 0x22b0ddd3940>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(325.45833333333337, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
